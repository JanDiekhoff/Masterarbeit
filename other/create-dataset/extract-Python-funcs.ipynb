# %%
# %%time
import pandas as pd
import ast

data = pd.read_parquet("data/Python-data.parquet")
df = pd.DataFrame(data)

# Create a new DataFrame to store the extracted functions
functions_data = []
error_counter = 0

# Function to extract function definitions from Python code
def extract_functions(code, error_counter):
    functions = []
    try:
        # Parse the code into an AST
        tree = ast.parse(code)
        # Iterate over all nodes in the AST
        for node in ast.walk(tree):
            # Check if the node is a function definition
            if isinstance(node, ast.FunctionDef):
                # Extract the function name and its definition
                function_name = node.name
                params = [arg.arg for arg in node.args.args]
                function_code = ast.get_source_segment(code, node)
                # Check for a docstring
                docstring = ast.get_docstring(node)
                functions.append({
                    'name': function_name,
                    'full_code': function_code,
                    'body': function_code.split(r"):")[1] if r"):" in function_code else None ,
                    'params':params,
                    'docstring': docstring
                })
    except SyntaxError as e:
        print(f"Syntax error in code: {e}")
        error_counter += 1
    return functions, error_counter


# Iterate through each row in the dataset and extract functions
for index, row in df.iterrows():
    code_content = row['content']  # Replace with the actual column name containing code
    extracted_functions, error_counter = extract_functions(code_content, error_counter)
    for func in extracted_functions:
        functions_data.append({
            'file_id': row['__index_level_0__'],  # Replace with the actual identifier for each code file
            'name': func['name'],
            'body': func['body'],
            'full_code': func['full_code'],
            'docstring': func['docstring'],
            'params':func['params'],
            'language':'Python',
        })
    if not index % 500:
        print(index, " ", error_counter)

# Convert the list of extracted functions to a DataFrame
functions_df = pd.DataFrame(functions_data)

functions_df.to_csv("data/python-extracted.csv")
functions_df
# Out:
# 0   0
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 28)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 138)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 9)
# Syntax error in code: unexpected indent (<unknown>, line 23)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 27)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 174)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 26)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 39)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 82)
# Syntax error in code: invalid syntax (<unknown>, line 8)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 188)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 59)
# Syntax error in code: invalid syntax (<unknown>, line 20)
# Syntax error in code: invalid syntax (<unknown>, line 4)
# Syntax error in code: cannot assign to None (<unknown>, line 37)
# Syntax error in code: invalid syntax (<unknown>, line 64)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 99)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 21)
# Syntax error in code: expected ':' (<unknown>, line 1)
# Syntax error in code: multiple exception types must be parenthesized (<unknown>, line 329)
# 500   20
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 44)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 29)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 33)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 24)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 30)
# Syntax error in code: leading zeros in decimal integer literals are not permitted; use an 0o prefix for octal integers (<unknown>, line 30)
# Syntax error in code: invalid syntax (<unknown>, line 1514)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 48)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 69)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 18)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 17)
# Syntax error in code: invalid syntax (<unknown>, line 404)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 21)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 18)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 27)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 46)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 9)
# Syntax error in code: inconsistent use of tabs and spaces in indentation (<unknown>, line 180)
# Syntax error in code: multiple exception types must be parenthesized (<unknown>, line 56)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 65)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 167)
# Syntax error in code: invalid syntax (<unknown>, line 170)
# 1000   42
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 53)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 8)
# Syntax error in code: invalid syntax. Perhaps you forgot a comma? (<unknown>, line 9)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 135)
# Syntax error in code: invalid syntax (<unknown>, line 89)
# Syntax error in code: leading zeros in decimal integer literals are not permitted; use an 0o prefix for octal integers (<unknown>, line 312)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 155)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 255)
# Syntax error in code: invalid non-printable character U+FEFF (<unknown>, line 1)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 16)
# Syntax error in code: unexpected indent (<unknown>, line 26)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 16)
# Syntax error in code: multiple exception types must be parenthesized (<unknown>, line 31)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 22)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 9)
# Syntax error in code: invalid syntax (<unknown>, line 1)
# Syntax error in code: invalid syntax (<unknown>, line 7)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 230)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 69)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 40)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 4)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 25)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 31)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 87)
# Syntax error in code: invalid syntax (<unknown>, line 1)
# 1500   67
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 29)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 42)
# Syntax error in code: invalid syntax (<unknown>, line 10)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 18)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 87)
# Syntax error in code: multiple exception types must be parenthesized (<unknown>, line 66)
# Syntax error in code: invalid syntax (<unknown>, line 68)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 4)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 11)
# Syntax error in code: invalid syntax (<unknown>, line 17)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 137)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 21)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 41)
# Syntax error in code: expected ':' (<unknown>, line 344)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 121)
# Syntax error in code: multiple exception types must be parenthesized (<unknown>, line 124)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 423)
# Syntax error in code: invalid syntax (<unknown>, line 67)
# Syntax error in code: invalid syntax (<unknown>, line 210)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 90)
# Syntax error in code: invalid syntax (<unknown>, line 3)
# Syntax error in code: invalid syntax (<unknown>, line 1)
# 2000   89
# Syntax error in code: invalid syntax (<unknown>, line 8)
# Syntax error in code: invalid syntax (<unknown>, line 8)
# Syntax error in code: invalid syntax (<unknown>, line 168)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 30)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 20)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 35)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 17)
# Syntax error in code: multiple exception types must be parenthesized (<unknown>, line 58)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 13)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 5)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 13)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 37)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 13)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 13)
# Syntax error in code: invalid syntax (<unknown>, line 38)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 9)
# Syntax error in code: multiple exception types must be parenthesized (<unknown>, line 43)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 5)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 146)
# Syntax error in code: Lambda expression parameters cannot be parenthesized (<unknown>, line 69)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 8)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 108)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 78)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 274)
# Syntax error in code: inconsistent use of tabs and spaces in indentation (<unknown>, line 229)
# Syntax error in code: '(' was never closed (<unknown>, line 4)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 14)
# Syntax error in code: inconsistent use of tabs and spaces in indentation (<unknown>, line 11)
# 2500   117
# Syntax error in code: unmatched ']' (<unknown>, line 151)
# Syntax error in code: invalid syntax. Perhaps you forgot a comma? (<unknown>, line 268)
# Syntax error in code: invalid syntax (<unknown>, line 7)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 120)
# Syntax error in code: invalid decimal literal (<unknown>, line 84)
# Syntax error in code: expected an indented block after function definition on line 1 (<unknown>, line 2)
# Syntax error in code: invalid decimal literal (<unknown>, line 1)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 59)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 25)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 94)
# Syntax error in code: inconsistent use of tabs and spaces in indentation (<unknown>, line 26)
# Syntax error in code: invalid non-printable character U+FEFF (<unknown>, line 1)
# Syntax error in code: multiple exception types must be parenthesized (<unknown>, line 1108)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 3)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 10)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 208)
# 3000   133
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 89)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 137)
# Syntax error in code: multiple exception types must be parenthesized (<unknown>, line 94)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 50)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 50)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 20)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 23)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 7)
# Syntax error in code: invalid syntax (<unknown>, line 9)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 75)
# Syntax error in code: multiple exception types must be parenthesized (<unknown>, line 47)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 15)
# 3500   145
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 44)
# Syntax error in code: multiple exception types must be parenthesized (<unknown>, line 93)
# Syntax error in code: invalid syntax (<unknown>, line 65)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 428)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 217)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 33)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 58)
# Syntax error in code: invalid syntax (<unknown>, line 5)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 72)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 28)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 116)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 73)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 5)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 130)
# Syntax error in code: invalid syntax (<unknown>, line 1)
# Syntax error in code: unindent does not match any outer indentation level (<unknown>, line 19)
# Syntax error in code: Missing parentheses in call to 'exec'. Did you mean exec(...)? (<unknown>, line 9)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 330)
# Syntax error in code: expected an indented block after function definition on line 89 (<unknown>, line 93)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 31)
# Syntax error in code: unindent does not match any outer indentation level (<unknown>, line 36)
# 4000   166
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 40)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 15)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 44)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 9)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 131)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 38)
# Syntax error in code: invalid syntax (<unknown>, line 41)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 1)
# Syntax error in code: invalid syntax (<unknown>, line 1)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 39)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 6)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 34)
# Syntax error in code: inconsistent use of tabs and spaces in indentation (<unknown>, line 36)
# Syntax error in code: cannot assign to None (<unknown>, line 115)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 97)
# Syntax error in code: inconsistent use of tabs and spaces in indentation (<unknown>, line 58)
# 4500   182
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 1668)
# Syntax error in code: invalid syntax (<unknown>, line 34)
# Syntax error in code: multiple exception types must be parenthesized (<unknown>, line 100)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 21)
# Syntax error in code: invalid syntax (<unknown>, line 1)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 562)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 627)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 201)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 29)
# Syntax error in code: multiple exception types must be parenthesized (<unknown>, line 588)
# Syntax error in code: invalid syntax (<unknown>, line 1)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 19)
# Syntax error in code: inconsistent use of tabs and spaces in indentation (<unknown>, line 128)
# 5000   195
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 50)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 78)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 125)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 17)
# Syntax error in code: invalid non-printable character U+FEFF (<unknown>, line 1)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 14)
# Syntax error in code: leading zeros in decimal integer literals are not permitted; use an 0o prefix for octal integers (<unknown>, line 27)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 82)
# Syntax error in code: invalid decimal literal (<unknown>, line 87)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 44)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 20)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 16)
# Syntax error in code: inconsistent use of tabs and spaces in indentation (<unknown>, line 26)
# Syntax error in code: leading zeros in decimal integer literals are not permitted; use an 0o prefix for octal integers (<unknown>, line 119)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 87)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 123)
# Syntax error in code: multiple exception types must be parenthesized (<unknown>, line 70)
# Syntax error in code: invalid syntax (<unknown>, line 45)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 52)
# Syntax error in code: invalid syntax (<unknown>, line 5)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 182)
# 5500   216
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 5)
# Syntax error in code: invalid syntax (<unknown>, line 12)
# Syntax error in code: multiple exception types must be parenthesized (<unknown>, line 82)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 6)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 561)
# Syntax error in code: multiple exception types must be parenthesized (<unknown>, line 90)
# Syntax error in code: multiple exception types must be parenthesized (<unknown>, line 532)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 55)
# Syntax error in code: multiple exception types must be parenthesized (<unknown>, line 193)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 39)
# Syntax error in code: multiple exception types must be parenthesized (<unknown>, line 31)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 40)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 22)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 37)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 25)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 4)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 181)
# Syntax error in code: multiple exception types must be parenthesized (<unknown>, line 59)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 205)
# Syntax error in code: invalid syntax (<unknown>, line 8)
# Syntax error in code: multiple exception types must be parenthesized (<unknown>, line 70)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 36)
# 6000   238
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 7)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 71)
# Syntax error in code: invalid decimal literal (<unknown>, line 1359)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 33)
# Syntax error in code: multiple exception types must be parenthesized (<unknown>, line 121)
# Syntax error in code: invalid syntax (<unknown>, line 5)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 16)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 89)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 360)
# Syntax error in code: leading zeros in decimal integer literals are not permitted; use an 0o prefix for octal integers (<unknown>, line 189)
# Syntax error in code: expected an indented block after class definition on line 25 (<unknown>, line 26)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 12)
# Syntax error in code: multiple exception types must be parenthesized (<unknown>, line 25)
# Syntax error in code: invalid decimal literal (<unknown>, line 1)
# Syntax error in code: expected an indented block after 'if' statement on line 34 (<unknown>, line 35)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 74)
# Syntax error in code: multiple exception types must be parenthesized (<unknown>, line 111)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 18)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 21)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 121)
# 6500   258
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 30)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 76)
# Syntax error in code: multiple exception types must be parenthesized (<unknown>, line 58)
# Syntax error in code: invalid syntax (<unknown>, line 13)
# Syntax error in code: invalid non-printable character U+FEFF (<unknown>, line 1)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 83)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 57)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 12)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 25)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 13)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 15)
# Syntax error in code: invalid syntax (<unknown>, line 2)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 70)
# Syntax error in code: leading zeros in decimal integer literals are not permitted; use an 0o prefix for octal integers (<unknown>, line 70)
# Syntax error in code: multiple exception types must be parenthesized (<unknown>, line 44)
# Syntax error in code: invalid syntax (<unknown>, line 51)
# Syntax error in code: invalid syntax (<unknown>, line 20)
# 7000   275
# Syntax error in code: invalid syntax (<unknown>, line 43)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 90)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 22)
# Syntax error in code: invalid syntax (<unknown>, line 114)
# Syntax error in code: multiple exception types must be parenthesized (<unknown>, line 51)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 55)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 117)
# Syntax error in code: invalid decimal literal (<unknown>, line 122)
# Syntax error in code: invalid syntax (<unknown>, line 34)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 241)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 75)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 4)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 72)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 20)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 908)
# Syntax error in code: invalid syntax (<unknown>, line 1)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 94)
# Syntax error in code: multiple exception types must be parenthesized (<unknown>, line 175)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 25)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 27)
# Syntax error in code: invalid syntax (<unknown>, line 40)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 40)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 77)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 356)
# 7500   299
# Syntax error in code: multiple exception types must be parenthesized (<unknown>, line 74)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 10)
# Syntax error in code: multiple exception types must be parenthesized (<unknown>, line 59)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 12)
# Syntax error in code: invalid syntax (<unknown>, line 6029)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 132)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 4)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 29)
# Syntax error in code: invalid syntax (<unknown>, line 1)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 40)
# Syntax error in code: multiple exception types must be parenthesized (<unknown>, line 20)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 23)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 21)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 27)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 29)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 19)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 76)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 16)
# Syntax error in code: leading zeros in decimal integer literals are not permitted; use an 0o prefix for octal integers (<unknown>, line 94)
# Syntax error in code: invalid decimal literal (<unknown>, line 23)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 41)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 179)
# 8000   321
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 38)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 29)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 36)
# Syntax error in code: multiple exception types must be parenthesized (<unknown>, line 245)
# Syntax error in code: expected an indented block after 'for' statement on line 6 (<unknown>, line 7)
# Syntax error in code: leading zeros in decimal integer literals are not permitted; use an 0o prefix for octal integers (<unknown>, line 793)
# Syntax error in code: multiple exception types must be parenthesized (<unknown>, line 49)
# Syntax error in code: multiple exception types must be parenthesized (<unknown>, line 6)
# Syntax error in code: Missing parentheses in call to 'exec'. Did you mean exec(...)? (<unknown>, line 45)
# Syntax error in code: '(' was never closed (<unknown>, line 10)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 36)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 91)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 13)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 7)
# Syntax error in code: invalid syntax (<unknown>, line 366)
# Syntax error in code: inconsistent use of tabs and spaces in indentation (<unknown>, line 57)
# Syntax error in code: invalid syntax (<unknown>, line 1)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 692)
# Syntax error in code: invalid syntax (<unknown>, line 1867)
# 8500   340
# Syntax error in code: invalid decimal literal (<unknown>, line 63)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 29)
# Syntax error in code: expected an indented block after function definition on line 1 (<unknown>, line 2)
# Syntax error in code: multiple exception types must be parenthesized (<unknown>, line 28)
# Syntax error in code: unexpected indent (<unknown>, line 47)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 836)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 7)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 5)
# Syntax error in code: invalid syntax (<unknown>, line 64)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 62)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 37)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 29)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 8)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 29)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 39)
# Syntax error in code: unexpected indent (<unknown>, line 5)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 41)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 24)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 119)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 17)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 355)
# 9000   361
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 7)
# Syntax error in code: multiple exception types must be parenthesized (<unknown>, line 124)
# Syntax error in code: invalid syntax (<unknown>, line 3)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 46)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 153)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 87)
# Syntax error in code: multiple exception types must be parenthesized (<unknown>, line 566)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 18)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 33)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 47)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 35)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 56)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 161)
# Syntax error in code: multiple exception types must be parenthesized (<unknown>, line 583)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 30)
# Syntax error in code: invalid syntax (<unknown>, line 127)
# Syntax error in code: inconsistent use of tabs and spaces in indentation (<unknown>, line 24)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 238)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 37)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 21)
# Syntax error in code: expected ':' (<unknown>, line 7)
# Syntax error in code: unmatched ')' (<unknown>, line 106)
# Syntax error in code: invalid non-printable character U+FEFF (<unknown>, line 1)
# 9500   384
# Syntax error in code: invalid syntax (<unknown>, line 48)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 89)
# Syntax error in code: inconsistent use of tabs and spaces in indentation (<unknown>, line 185)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 152)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 80)
# Syntax error in code: invalid syntax (<unknown>, line 1)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 43)
# Syntax error in code: invalid syntax (<unknown>, line 36)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 32)
# Syntax error in code: multiple exception types must be parenthesized (<unknown>, line 32)
# Syntax error in code: invalid syntax (<unknown>, line 13)
# Syntax error in code: invalid syntax (<unknown>, line 6)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 441)
# Syntax error in code: multiple exception types must be parenthesized (<unknown>, line 197)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 41)
# Syntax error in code: invalid syntax (<unknown>, line 7)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 43)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 78)
# Syntax error in code: invalid syntax (<unknown>, line 1)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 62)
# Syntax error in code: multiple exception types must be parenthesized (<unknown>, line 452)
# Syntax error in code: invalid syntax (<unknown>, line 191)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 11)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 45)
# Syntax error in code: multiple exception types must be parenthesized (<unknown>, line 308)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 24)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 14)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 36)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 39)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 52)
# Syntax error in code: Missing parentheses in call to 'print'. Did you mean print(...)? (<unknown>, line 5)
# Syntax error in code: multiple exception types must be parenthesized (<unknown>, line 420)
# CPU times: total: 11min 14s
# Wall time: 12min
#        file_id                        name  \
# 0       210001                    __init__
# 1       210001                 train_model
# 2       210002    _canonicalize_experiment
# 3       210002                       setUp
# 4       210002  _mock_all_summary_metadata
# ...        ...                         ...
# 81761   219998      test_find_start_codons
# 81762   219998             test_transcribe
# 81763   219998             test_is_gc_rich
# 81764   219998             test_gc_content
# 81765   219999                    read_cfg
#
#                                                     body  \
# 0                                         \n        pass
# 1      \n        if os.path.exists(config_path) and (...
# 2      \n    """Sorts the repeated fields of an Exper...
# 3      \n        self._mock_tb_context = base_plugin....
# 4      \n        result = {}\n        hparams_content...
# ...                                                  ...
# 81761  \n    """New test to test the function to find...
# 81762  \n    assert DNA('GTC').transcribe() == 'GAC'\...
# 81763       \n    assert DNA('GTGT').gc_content() == 0.5
# 81764  \n    assert DNA('ATTTATGGCC').gc_content == 0...
# 81765                                         \n    pass
#
#                                                full_code  \
# 0                      def __init__(self):\n        pass
# 1      def train_model(self, config_path):\n        i...
# 2      def _canonicalize_experiment(exp):\n    """Sor...
# 3      def setUp(self):\n        self._mock_tb_contex...
# 4      def _mock_all_summary_metadata(self):\n       ...
# ...                                                  ...
# 81761  def test_find_start_codons():\n    """New test...
# 81762  def test_transcribe():\n    assert DNA('GTC')....
# 81763  def test_is_gc_rich():\n    assert DNA('GTGT')...
# 81764  def test_gc_content():\n    assert DNA('ATTTAT...
# 81765          def read_cfg(model_repository):\n    pass
#
#                                                docstring               params  \
# 0                                                   None               [self]
# 1                                                   None  [self, config_path]
# 2      Sorts the repeated fields of an Experiment mes...                [exp]
# 3                                                   None               [self]
# 4                                                   None               [self]
# ...                                                  ...                  ...
# 81761  New test to test the function to find start co...                   []
# 81762                                               None                   []
# 81763                                               None                   []
# 81764                                               None                   []
# 81765                                               None   [model_repository]
#
#       language
# 0       Python
# 1       Python
# 2       Python
# 3       Python
# 4       Python
# ...        ...
# 81761   Python
# 81762   Python
# 81763   Python
# 81764   Python
# 81765   Python
#
# [81766 rows x 7 columns]
